# %% [markdown]
# <a href="https://colab.research.google.com/github/Noob919/Feature_selection/blob/main/OWA/Cancer_OWA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from functools import reduce
from itertools import combinations,permutations

# %%
rank1 = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "Chi_2").set_index('Attributes_Names')

rank2  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "Tree_based_method").set_index('Attributes_Names')
 
rank3  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "permutation_method_mean").set_index('Attributes_Names')
rank5  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "PCA").set_index('Attributes_Names')
rank4  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "permutation_method_std").set_index('Attributes_Names')
rank6  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "F_test").set_index('Attributes_Names')
rank7  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "mutual_info").set_index('Attributes_Names')
rank8  = pd.read_excel("/content/cancer_dataset.xlsx",sheet_name = "Pearson_Correlation").set_index('Attributes_Names')

# %%
ranks = [rank1,rank2,rank3,rank4,rank5,rank6,rank7,rank8]
final_df = reduce(lambda  left,right: pd.merge(left,right,on=['Attributes_Names'],how='inner'), ranks)
final_df
# Out:
#                          rank_chi      rank_tree     rank_per_mean  \
# Attributes_Names
# area_worst                    1.0            2.0                 1
# area_mean                     2.0            8.0                 3
# area_se                       3.0           10.0                 4
# perimeter_worst               4.0            1.0                 2
# perimeter_mean                5.0            6.0                 8
# radius_worst                  6.0            4.0                 6
# radius_mean                   7.0            9.0                 5
# perimeter_se                  8.0           14.0                29
# texture_worst                 9.0           13.0                 7
# texture_mean                 10.0           16.0                30
# concavity_worst              11.0           11.0                 9
# radius_se                    12.0           19.0                10
# concavity_mean               13.0            7.0                27
# compactness_worst            14.0           12.0                19
# concave points_worst         15.0            3.0                25
# concave points_mean          16.0            5.0                24
# compactness_mean             17.0           18.0                28
# symmetry_worst               18.0           15.0                11
# concavity_se                 19.0           20.0                15
# compactness_se               20.0           28.0                12
# smoothness_worst             21.0           17.0                26
# concave points_se            22.0           29.0                16
# symmetry_mean                23.0           23.0                23
# fractal_dimension_worst      24.0           21.0                21
# smoothness_mean              25.0           24.0                20
# texture_se                   26.0           27.0                22
# fractal_dimension_se         27.0           26.0                18
# smoothness_se                28.0           25.0                14
# symmetry_se                  29.0           22.0                17
# fractal_dimension_mean       30.0           30.0                13
#
#                          rank_P_std  rank_pca  rank_f_test  Mutual_info_rank  \
# Attributes_Names
# area_worst                        2         1            7                 2
# area_mean                         3         2            8                 8
# area_se                           5         3           15                10
# perimeter_worst                   1         4            2                 1
# perimeter_mean                    8         5            5                 6
# radius_worst                      4         6            3                 3
# radius_mean                       7         7            6                 9
# perimeter_se                     13         9           14                12
# texture_worst                     6         8           16                17
# texture_mean                     10        10           19                21
# concavity_worst                  11        12           10                11
# radius_se                        23        11           13                13
# concavity_mean                   20        14            9                 7
# compactness_worst                12        13           12                15
# concave points_worst             16        15            1                 5
# concave points_mean              18        16            4                 4
# compactness_mean                 19        17           11                14
# symmetry_worst                   15        18           18                19
# concavity_se                     26        19           25                16
# compactness_se                   25        22           24                22
# smoothness_worst                 22        21           17                20
# concave points_se                27        24           20                18
# symmetry_mean                    17        20           22                24
# fractal_dimension_worst          21        25           23                25
# smoothness_mean                  14        23           21                23
# texture_se                        9        30           28                30
# fractal_dimension_se             29        26           26                26
# smoothness_se                    30        27           27                29
# symmetry_se                      28        28           30                27
# fractal_dimension_mean           24        29           29                28
#
#                          rank_pearson
# Attributes_Names
# area_worst                          6
# area_mean                           8
# area_se                            15
# perimeter_worst                     2
# perimeter_mean                      5
# radius_worst                        4
# radius_mean                         7
# perimeter_se                       14
# texture_worst                      16
# texture_mean                       19
# concavity_worst                    10
# radius_se                          13
# concavity_mean                      9
# compactness_worst                  12
# concave points_worst                1
# concave points_mean                 3
# compactness_mean                   11
# symmetry_worst                     18
# concavity_se                       25
# compactness_se                     24
# smoothness_worst                   17
# concave points_se                  20
# symmetry_mean                      22
# fractal_dimension_worst            23
# smoothness_mean                    21
# texture_se                         28
# fractal_dimension_se               26
# smoothness_se                      30
# symmetry_se                        27
# fractal_dimension_mean             29

# %%
negative_df = final_df*-1
negative_df
# Out:
#                          rank_chi     rank_tree    rank_per_mean  rank_P_std  \
# Attributes_Names
# area_worst                   -1.0          -2.0               -1          -2
# area_mean                    -2.0          -8.0               -3          -3
# area_se                      -3.0         -10.0               -4          -5
# perimeter_worst              -4.0          -1.0               -2          -1
# perimeter_mean               -5.0          -6.0               -8          -8
# radius_worst                 -6.0          -4.0               -6          -4
# radius_mean                  -7.0          -9.0               -5          -7
# perimeter_se                 -8.0         -14.0              -29         -13
# texture_worst                -9.0         -13.0               -7          -6
# texture_mean                -10.0         -16.0              -30         -10
# concavity_worst             -11.0         -11.0               -9         -11
# radius_se                   -12.0         -19.0              -10         -23
# concavity_mean              -13.0          -7.0              -27         -20
# compactness_worst           -14.0         -12.0              -19         -12
# concave points_worst        -15.0          -3.0              -25         -16
# concave points_mean         -16.0          -5.0              -24         -18
# compactness_mean            -17.0         -18.0              -28         -19
# symmetry_worst              -18.0         -15.0              -11         -15
# concavity_se                -19.0         -20.0              -15         -26
# compactness_se              -20.0         -28.0              -12         -25
# smoothness_worst            -21.0         -17.0              -26         -22
# concave points_se           -22.0         -29.0              -16         -27
# symmetry_mean               -23.0         -23.0              -23         -17
# fractal_dimension_worst     -24.0         -21.0              -21         -21
# smoothness_mean             -25.0         -24.0              -20         -14
# texture_se                  -26.0         -27.0              -22          -9
# fractal_dimension_se        -27.0         -26.0              -18         -29
# smoothness_se               -28.0         -25.0              -14         -30
# symmetry_se                 -29.0         -22.0              -17         -28
# fractal_dimension_mean      -30.0         -30.0              -13         -24
#
#                          rank_pca  rank_f_test  Mutual_info_rank  rank_pearson
# Attributes_Names
# area_worst                     -1           -7                -2            -6
# area_mean                      -2           -8                -8            -8
# area_se                        -3          -15               -10           -15
# perimeter_worst                -4           -2                -1            -2
# perimeter_mean                 -5           -5                -6            -5
# radius_worst                   -6           -3                -3            -4
# radius_mean                    -7           -6                -9            -7
# perimeter_se                   -9          -14               -12           -14
# texture_worst                  -8          -16               -17           -16
# texture_mean                  -10          -19               -21           -19
# concavity_worst               -12          -10               -11           -10
# radius_se                     -11          -13               -13           -13
# concavity_mean                -14           -9                -7            -9
# compactness_worst             -13          -12               -15           -12
# concave points_worst          -15           -1                -5            -1
# concave points_mean           -16           -4                -4            -3
# compactness_mean              -17          -11               -14           -11
# symmetry_worst                -18          -18               -19           -18
# concavity_se                  -19          -25               -16           -25
# compactness_se                -22          -24               -22           -24
# smoothness_worst              -21          -17               -20           -17
# concave points_se             -24          -20               -18           -20
# symmetry_mean                 -20          -22               -24           -22
# fractal_dimension_worst       -25          -23               -25           -23
# smoothness_mean               -23          -21               -23           -21
# texture_se                    -30          -28               -30           -28
# fractal_dimension_se          -26          -26               -26           -26
# smoothness_se                 -27          -27               -29           -30
# symmetry_se                   -28          -30               -27           -27
# fractal_dimension_mean        -29          -29               -28           -29

# %%
perms = list(permutations(final_df.index,2)) 
perm_df = pd.DataFrame(perms, columns = ['feature A', 'feature B'])

# %%
rank_chi = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_chi'] > negative_df.T[perm_df['feature B'][i]]['rank_chi']):
    rank_chi.append(1)
  else: 
    rank_chi.append(0)

perm_df = perm_df.merge(pd.Series(rank_chi, name = 'Chi2').to_frame(), left_index=True, right_index=True)

# %%
rank_tree = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_tree'] > negative_df.T[perm_df['feature B'][i]]['rank_tree']):
    rank_tree.append(1)
  else: 
    rank_tree.append(0)

perm_df = perm_df.merge(pd.Series(rank_tree, name = 'tree').to_frame(), left_index=True, right_index=True)

# %%
rank_per_mean = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_per_mean'] > negative_df.T[perm_df['feature B'][i]]['rank_per_mean']):
    rank_per_mean.append(1)
  else: 
    rank_per_mean.append(0)

perm_df = perm_df.merge(pd.Series(rank_per_mean, name = 'per_mean').to_frame(), left_index=True, right_index=True)

# %%
rank_P_std = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_P_std'] > negative_df.T[perm_df['feature B'][i]]['rank_P_std']):
    rank_P_std.append(1)
  else: 
    rank_P_std.append(0)

perm_df = perm_df.merge(pd.Series(rank_P_std, name = 'per_std').to_frame(), left_index=True, right_index=True)

# %%
rank_pca = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_pca'] > negative_df.T[perm_df['feature B'][i]]['rank_pca']):
    rank_pca.append(1)
  else: 
    rank_pca.append(0)

perm_df = perm_df.merge(pd.Series(rank_pca, name = 'rank_pca').to_frame(), left_index=True, right_index=True)

# %%
rank_f_test = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_f_test'] > negative_df.T[perm_df['feature B'][i]]['rank_f_test']):
    rank_f_test.append(1)
  else: 
    rank_f_test.append(0)

perm_df = perm_df.merge(pd.Series(rank_f_test, name = 'rank_f_test').to_frame(), left_index=True, right_index=True)

# %%
rank_mutual_info = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]][ 'Mutual_info_rank'] > negative_df.T[perm_df['feature B'][i]]['Mutual_info_rank']):
    rank_mutual_info.append(1)
  else: 
    rank_mutual_info.append(0)

perm_df = perm_df.merge(pd.Series(rank_mutual_info, name = 'rank_mutual').to_frame(), left_index=True, right_index=True)

# %%
rank_pearson = []
for i in range(0,perm_df.shape[0]):
  if(negative_df.T[perm_df['feature A'][i]]['rank_pearson'] > negative_df.T[perm_df['feature B'][i]]['rank_pearson']):
    rank_pearson.append(1)
  else: 
    rank_pearson.append(0)

perm_df = perm_df.merge(pd.Series(rank_pearson, name = 'rank_pearson').to_frame(), left_index=True, right_index=True)

# %%
perm_df[:60]

# %%
Name = pd.DataFrame(list(negative_df.index),columns = ['Attributes_Name'])
Name

# %%
PS_Chi = []
for i in negative_df.index:
    PS_Chi.append((((perm_df[perm_df['feature A'] == i]['Chi2'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_Chi, name = 'PS_Chi').to_frame(), left_index=True, right_index=True)
Name
# Out:
#             Attributes_Name    PS_Chi
# 0                area_worst  1.000000
# 1                 area_mean  0.965517
# 2                   area_se  0.931034
# 3           perimeter_worst  0.896552
# 4            perimeter_mean  0.862069
# 5              radius_worst  0.827586
# 6               radius_mean  0.793103
# 7              perimeter_se  0.758621
# 8             texture_worst  0.724138
# 9              texture_mean  0.689655
# 10          concavity_worst  0.655172
# 11                radius_se  0.620690
# 12           concavity_mean  0.586207
# 13        compactness_worst  0.551724
# 14     concave points_worst  0.517241
# 15      concave points_mean  0.482759
# 16         compactness_mean  0.448276
# 17           symmetry_worst  0.413793
# 18             concavity_se  0.379310
# 19           compactness_se  0.344828
# 20         smoothness_worst  0.310345
# 21        concave points_se  0.275862
# 22            symmetry_mean  0.241379
# 23  fractal_dimension_worst  0.206897
# 24          smoothness_mean  0.172414
# 25               texture_se  0.137931
# 26     fractal_dimension_se  0.103448
# 27            smoothness_se  0.068966
# 28              symmetry_se  0.034483
# 29   fractal_dimension_mean  0.000000

# %%
PS_Tree = []
for i in negative_df.index:
    PS_Tree.append((((perm_df[perm_df['feature A'] == i]['tree'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_Tree, name = 'PS_Tree').to_frame(), left_index=True, right_index=True)

# %%
PS_per_mean = []
for i in negative_df.index:
    PS_per_mean.append((((perm_df[perm_df['feature A'] == i]['per_mean'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_per_mean, name = 'PS_per_mean').to_frame(), left_index=True, right_index=True)

# %%
PS_per_std = []
for i in negative_df.index:
    PS_per_std.append((((perm_df[perm_df['feature A'] == i]['per_std'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_per_std, name = 'PS_per_std').to_frame(), left_index=True, right_index=True)

# %%
PS_pca = []
for i in negative_df.index:
    PS_pca.append((((perm_df[perm_df['feature A'] == i]['rank_pca'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_pca, name = 'PS_pca').to_frame(), left_index=True, right_index=True)

# %%
PS_f_test = []
for i in negative_df.index:
    PS_f_test.append((((perm_df[perm_df['feature A'] == i]['rank_f_test'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_f_test, name = 'PS_f_test').to_frame(), left_index=True, right_index=True)

# %%
PS_mutual = []
for i in negative_df.index:
    PS_mutual.append((((perm_df[perm_df['feature A'] == i]['rank_mutual'].sum())/29)))
    
Name = Name.merge(pd.Series(PS_mutual, name = 'PS_mutual').to_frame(), left_index=True, right_index=True)

# %%
PS_pearson = []
for i in negative_df.index:
    PS_pearson.append((((perm_df[perm_df['feature A'] == i]['rank_pearson'].sum())/20)))
    
Name = Name.merge(pd.Series(PS_pearson, name = 'PS_pearson').to_frame(), left_index=True, right_index=True)

# %%
PS = Name.set_index('Attributes_Name')
PS
# Out:
#                            PS_Chi   PS_Tree  PS_per_mean  PS_per_std  \
# Attributes_Name
# area_worst               1.000000  0.965517     1.000000    0.965517
# area_mean                0.965517  0.758621     0.931034    0.931034
# area_se                  0.931034  0.689655     0.896552    0.862069
# perimeter_worst          0.896552  1.000000     0.965517    1.000000
# perimeter_mean           0.862069  0.827586     0.758621    0.758621
# radius_worst             0.827586  0.896552     0.827586    0.896552
# radius_mean              0.793103  0.724138     0.862069    0.793103
# perimeter_se             0.758621  0.551724     0.034483    0.586207
# texture_worst            0.724138  0.586207     0.793103    0.827586
# texture_mean             0.689655  0.482759     0.000000    0.689655
# concavity_worst          0.655172  0.655172     0.724138    0.655172
# radius_se                0.620690  0.379310     0.689655    0.241379
# concavity_mean           0.586207  0.793103     0.103448    0.344828
# compactness_worst        0.551724  0.620690     0.379310    0.620690
# concave points_worst     0.517241  0.931034     0.172414    0.482759
# concave points_mean      0.482759  0.862069     0.206897    0.413793
# compactness_mean         0.448276  0.413793     0.068966    0.379310
# symmetry_worst           0.413793  0.517241     0.655172    0.517241
# concavity_se             0.379310  0.344828     0.517241    0.137931
# compactness_se           0.344828  0.068966     0.620690    0.172414
# smoothness_worst         0.310345  0.448276     0.137931    0.275862
# concave points_se        0.275862  0.034483     0.482759    0.103448
# symmetry_mean            0.241379  0.241379     0.241379    0.448276
# fractal_dimension_worst  0.206897  0.310345     0.310345    0.310345
# smoothness_mean          0.172414  0.206897     0.344828    0.551724
# texture_se               0.137931  0.103448     0.275862    0.724138
# fractal_dimension_se     0.103448  0.137931     0.413793    0.034483
# smoothness_se            0.068966  0.172414     0.551724    0.000000
# symmetry_se              0.034483  0.275862     0.448276    0.068966
# fractal_dimension_mean   0.000000  0.000000     0.586207    0.206897
#
#                            PS_pca  PS_f_test  PS_mutual  PS_pearson
# Attributes_Name
# area_worst               1.000000   0.793103   0.965517        1.20
# area_mean                0.965517   0.758621   0.758621        1.10
# area_se                  0.931034   0.517241   0.689655        0.75
# perimeter_worst          0.896552   0.965517   1.000000        1.40
# perimeter_mean           0.862069   0.862069   0.827586        1.25
# radius_worst             0.827586   0.931034   0.931034        1.30
# radius_mean              0.793103   0.827586   0.724138        1.15
# perimeter_se             0.724138   0.551724   0.620690        0.80
# texture_worst            0.758621   0.482759   0.448276        0.70
# texture_mean             0.689655   0.379310   0.310345        0.55
# concavity_worst          0.620690   0.689655   0.655172        1.00
# radius_se                0.655172   0.586207   0.586207        0.85
# concavity_mean           0.551724   0.724138   0.793103        1.05
# compactness_worst        0.586207   0.620690   0.517241        0.90
# concave points_worst     0.517241   1.000000   0.862069        1.45
# concave points_mean      0.482759   0.896552   0.896552        1.35
# compactness_mean         0.448276   0.655172   0.551724        0.95
# symmetry_worst           0.413793   0.413793   0.379310        0.60
# concavity_se             0.379310   0.172414   0.482759        0.25
# compactness_se           0.275862   0.206897   0.275862        0.30
# smoothness_worst         0.310345   0.448276   0.344828        0.65
# concave points_se        0.206897   0.344828   0.413793        0.50
# symmetry_mean            0.344828   0.275862   0.206897        0.40
# fractal_dimension_worst  0.172414   0.241379   0.172414        0.35
# smoothness_mean          0.241379   0.310345   0.241379        0.45
# texture_se               0.000000   0.068966   0.000000        0.10
# fractal_dimension_se     0.137931   0.137931   0.137931        0.20
# smoothness_se            0.103448   0.103448   0.034483        0.00
# symmetry_se              0.068966   0.000000   0.103448        0.15
# fractal_dimension_mean   0.034483   0.034483   0.068966        0.05

# %%
def Q(r):
  a = 0.3
  b = 0.8
  if(r < a):
    q = 0
  
  elif(a <= r <= 0.8):
    q =(r-0.3)/(b-a)
    
  elif(r>0.8):
    q =1
    
  return q

# %%
w_chi = Q(1/8) - Q(0)
w_tree = Q(2/8) - Q(1/8)
w_per_mean = Q(3/8) - Q(2/8)
w_per_std = Q(4/8) - Q(3/8)
w_pca = Q(5/8) - Q(4/8)
w_f_test = Q(6/8) -Q(5/8)
w_mutual = Q(7/8) - Q(6/8)
w_pearson = Q(8/8) - Q(7/8)
w  = [w_chi,w_tree,w_per_mean,w_per_std,w_pca,w_f_test,w_mutual,w_pearson]

# %%
FS = []
for i in range(0,len(Name.index)):
  sum = 0 
  fs = PS.iloc[i].sort_values(ascending = False)
  for j in range(0,len(fs)):
    sum  = sum + fs[j]*w[j]
  FS.append(sum) 
FS
# Out:
# [0.9793103448275863,
#  0.8758620689655172,
#  0.7788793103448276,
#  0.9724137931034483,
#  0.8344827586206895,
#  0.8775862068965516,
#  0.7913793103448277,
#  0.6034482758620691,
#  0.664655172413793,
#  0.4875000000000001,
#  0.6603448275862069,
#  0.5844827586206897,
#  0.6189655172413794,
#  0.5844827586206897,
#  0.6620689655172414,
#  0.6327586206896552,
#  0.4482758620689655,
#  0.4551724137931034,
#  0.31767241379310346,
#  0.25189655172413794,
#  0.33620689655172414,
#  0.27931034482758627,
#  0.2655172413793104,
#  0.253448275862069,
#  0.2706896551724138,
#  0.08879310344827587,
#  0.13448275862068965,
#  0.06724137931034482,
#  0.08629310344827586,
#  0.040086206896551735]

# %%
Final_df  = Name.merge(pd.Series(FS, name = 'FinalScore').to_frame(), left_index=True, right_index=True)

# %%
Final_df  =  Final_df[['Attributes_Name','FinalScore']].sort_values(by = 'FinalScore', ascending = False)
Final_df
# Out:
#             Attributes_Name  FinalScore
# 0                area_worst    0.979310
# 3           perimeter_worst    0.972414
# 5              radius_worst    0.877586
# 1                 area_mean    0.875862
# 4            perimeter_mean    0.834483
# 6               radius_mean    0.791379
# 2                   area_se    0.778879
# 8             texture_worst    0.664655
# 14     concave points_worst    0.662069
# 10          concavity_worst    0.660345
# 15      concave points_mean    0.632759
# 12           concavity_mean    0.618966
# 7              perimeter_se    0.603448
# 11                radius_se    0.584483
# 13        compactness_worst    0.584483
# 9              texture_mean    0.487500
# 17           symmetry_worst    0.455172
# 16         compactness_mean    0.448276
# 20         smoothness_worst    0.336207
# 18             concavity_se    0.317672
# 21        concave points_se    0.279310
# 24          smoothness_mean    0.270690
# 22            symmetry_mean    0.265517
# 23  fractal_dimension_worst    0.253448
# 19           compactness_se    0.251897
# 26     fractal_dimension_se    0.134483
# 25               texture_se    0.088793
# 28              symmetry_se    0.086293
# 27            smoothness_se    0.067241
# 29   fractal_dimension_mean    0.040086
